# %%
# runner.py
import subprocess
import time

RUNTIME = 4 * 60 * 60  # 4시간(초)



while True:
    print("automation.py 시작")
    # stdout과 stderr를 실시간으로 받아서 터미널에 출력
    proc = subprocess.Popen(
        ["python", "automation.py"],
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        bufsize=1,
        text=True
    )

    try:
        start_time = time.time()
        # 실시간 출력 읽기 루프
        while True:
            # 한 줄씩 읽어서 출력
            line = proc.stdout.readline()
            if line:
                print("[automation.py]", line, end="")  # 이미 줄바꿈 포함됨
            # 프로세스가 끝나면 break
            if proc.poll() is not None:
                # 남아있는 출력 다 flush
                for line in proc.stdout:
                    print("[automation.py]", line, end="")
                break
            # 타임아웃 체크
            if time.time() - start_time > RUNTIME:
                raise subprocess.TimeoutExpired(cmd="automation.py", timeout=RUNTIME)
        # 여기까지 왔다는 것은:
        #  - RUNTIME 이내에 automation.py가 스스로 종료함
        print("automation.py가 자체 종료됨, 즉시 재시작")
    except subprocess.TimeoutExpired:
        print("4시간 경과, automation.py 강제 종료 후 재시작")
        proc.terminate()
        try:
            proc.wait(timeout=30)  # 30초 안에 정상 종료 기다림
        except subprocess.TimeoutExpired:
            proc.kill()           # 안 죽으면 강제 종료
        # 남아있는 출력 다 flush
        if proc.stdout:
            for line in proc.stdout:
                print("[automation.py]", line, end="")
        # 이후 while True 루프 다음 반복에서 재실행
# Out:
# automation.py 시작
# [automation.py] 시작!
# [automation.py] adb0 시작adb0 스레드 시작 (독립 루프)
# [automation.py]
# [automation.py] adb1 시작adb1 스레드 시작 (독립 루프)
# [automation.py]
# [automation.py] adb2 시작adb2 스레드 시작 (독립 루프)
# [automation.py]
# [automation.py] adb3 시작adb3 스레드 시작 (독립 루프)
# [automation.py]
# [automation.py] adb0 0 1 0 0 0 1
# [automation.py] adb1 1 0 0 0 0 1
# [automation.py] ================================================
# [automation.py] adb1 비어있는 큐 존재
# [automation.py] [['행군 대열1', 166.0, 267.75, 135.0, 201.0, 259.0, 276.0, 0.968714565038681], ['한가함', 168.0, 290.5, 146.0, 190.0, 283.0, 298.0, 0.9996464252471924], ['행군 대열2', 164.75, 322.5, 133.0, 202.0, 315.0, 330.0, 0.9735036194324493], ['한가함', 167.5, 345.0, 145.0, 190.0, 334.0, 356.0, 0.9989530444145203], ['행군 대열3', 164.75, 377.75, 133.0, 202.0, 370.0, 386.0, 0.995623379945755], ['해제하기', 168.0, 401.0, 139.0, 197.0, 392.0, 410.0, 0.99969881772995], ['행군 대열4', 165.25, 432.25, 133.0, 203.0, 424.0, 441.0, 0.9994387030601501], ['사용불가', 168.5, 455.5, 138.0, 199.0, 447.0, 464.0, 0.9992659091949463], ['행군 대열5', 164.0, 487.0, 133.0, 202.0, 479.0, 495.0, 0.9996188580989838], ['사용불가', 168.0, 510.5, 137.0, 199.0, 502.0, 519.0, 0.9718835949897766], ['행군 대열6', 165.0, 542.5, 133.0, 203.0, 535.0, 550.0, 0.9996779263019562], ['사용 불가', 167.5, 565.5, 139.0, 198.0, 557.0, 574.0, 0.9980247020721436]]
# [automation.py] ================================================
# [automation.py] adb2 0 0 0 0 0 1
# [automation.py] adb3 0 0 0 0 0 1
# [automation.py] adb1 stamina: 78
# [automation.py] ================================================
# [automation.py] adb3 비어있는 큐 존재
# [automation.py] [['행군 대열1', 166.0, 267.75, 135.0, 201.0, 259.0, 276.0, 0.9687193930149078], ['한가함', 168.0, 290.5, 146.0, 190.0, 283.0, 298.0, 0.9996472001075745], ['행군 대열2', 164.75, 322.5, 133.0, 202.0, 315.0, 330.0, 0.9775882661342621], ['한가함', 167.5, 345.0, 145.0, 190.0, 334.0, 356.0, 0.9988835453987122], ['행군 대열3', 164.75, 377.75, 133.0, 202.0, 370.0, 386.0, 0.9949188530445099], ['해제하기', 168.0, 401.0, 139.0, 197.0, 392.0, 410.0, 0.9996989369392395], ['행군 대열4', 165.25, 432.25, 133.0, 203.0, 424.0, 441.0, 0.9994352459907532], ['사용불가', 168.5, 455.5, 138.0, 199.0, 447.0, 464.0, 0.9992715120315552], ['행군 대열5', 164.0, 487.0, 133.0, 202.0, 479.0, 495.0, 0.999618798494339], ['사용불가', 168.0, 510.5, 137.0, 199.0, 502.0, 519.0, 0.9718835949897766], ['행군 대열6', 165.0, 542.5, 133.0, 203.0, 535.0, 550.0, 0.9996779263019562], ['사용 불가', 167.5, 565.5, 139.0, 198.0, 557.0, 574.0, 0.9980386197566986]]
# [automation.py] ================================================
# [automation.py] []
# [automation.py] adb3 stamina: 76
# [automation.py] []
# [automation.py] []
# [automation.py] []
# [automation.py] adb2 loop 30 진입
# [automation.py] adb3 과학기술 연구 시작작
# [automation.py] adb0 과학기술 연구 시작작
# [automation.py] adb0 loop 30 진입
# [automation.py] adb2 시작
# [automation.py] 607.25
# [automation.py] adb2 0 0 0 0 0 1
# [automation.py] ================================================
# [automation.py] adb2 비어있는 큐 존재
# [automation.py] [['복귀 중', 171.25, 267.75, 145.0, 190.0, 259.0, 276.0, 0.9986315369606018], ['00:01:15', 169.5, 290.0, 141.0, 198.0, 283.0, 297.0, 0.9646543860435486], ['행군 대열2', 164.75, 322.5, 133.0, 202.0, 315.0, 330.0, 0.9775309264659882], ['한가함', 168.5, 346.0, 146.0, 191.0, 337.0, 355.0, 0.9992277026176453], ['행군 대열3 01:1C', 199.33333333333334, 379.6666666666667, 133.0, 284.0, 370.0, 392.0, 0.9590992331504822], ['해제하기', 167.5, 401.0, 138.0, 197.0, 392.0, 410.0, 0.9996106624603271], ['행군 대열4', 165.5, 432.25, 133.0, 203.0, 424.0, 441.0, 0.9993417859077454], ['사용불가', 168.5, 455.5, 138.0, 199.0, 447.0, 464.0, 0.999156653881073], ['행군 대열5', 164.25, 487.0, 133.0, 202.0, 479.0, 495.0, 0.9989793300628662], ['사용불가', 167.5, 510.5, 137.0, 198.0, 502.0, 519.0, 0.998866081237793], ['행군 대열6', 165.25, 542.5, 133.0, 203.0, 535.0, 550.0, 0.9995723962783813], ['사용 불가', 168.0, 566.0, 139.0, 200.0, 557.0, 575.0, 0.9632367491722107]]
# [automation.py] ================================================
# [automation.py] adb2 stamina: 77
# [automation.py] adb0 보급품 수령 완료료
# [automation.py] adb0 시작
# [automation.py] adb0 0 1 0 0 0 1
# [automation.py] [['수령', 447.5, 433.5, 429.0, 466.0, 421.0, 446.0, 0.999882698059082], ['수령', 448.0, 558.0, 429.0, 467.0, 546.0, 570.0, 0.9997953772544861], ['이동', 447.25, 683.0, 425.0, 469.0, 667.0, 699.0, 0.9996850490570068]]
# [automation.py] adb2 과학기술 연구 시작작
# [automation.py] adb3 loop 30 진입
# [automation.py] []
# [automation.py] [['이동', 447.5, 398.5, 428.0, 467.0, 386.0, 411.0, 0.9998035430908203]]
# [automation.py] []
# [automation.py] adb1 loop 30 진입
# [automation.py] adb3 시작
# [automation.py] adb0 과학기술 연구 시작작
# [automation.py] adb0 시작
# [automation.py] adb1 시작
# [automation.py] adb3 0 0 0 0 0 0
# [automation.py] ================================================
# [automation.py] adb3 비어있는 큐 존재
# [automation.py] [['Lv14 치타 공격', 170.0, 267.5, 116.0, 218.0, 259.0, 276.0, 0.9861142834027609], ['00:00:26', 168.5, 289.25, 138.0, 199.0, 281.0, 298.0, 0.966135561466217], ['행군 대열2', 164.5, 322.5, 133.0, 202.0, 315.0, 330.0, 0.9556100070476532], ['한가함', 167.5, 345.0, 145.0, 190.0, 334.0, 356.0, 0.9989174008369446], ['행군 대열3', 165.0, 378.25, 133.0, 202.0, 371.0, 386.0, 0.9990524351596832], ['해제하기', 167.5, 401.0, 138.0, 197.0, 392.0, 410.0, 0.9996111989021301], ['행군 대열4', 165.75, 432.25, 133.0, 204.0, 424.0, 441.0, 0.9993995726108551], ['사용불가', 168.5, 455.5, 138.0, 199.0, 447.0, 464.0, 0.9990057349205017], ['행군 대열5', 164.0, 487.0, 133.0, 202.0, 479.0, 495.0, 0.9995241761207581], ['사용불가', 168.5, 510.5, 138.0, 199.0, 502.0, 519.0, 0.9935685992240906], ['행군 대열6', 165.0, 542.5, 133.0, 203.0, 535.0, 550.0, 0.9997371137142181], ['사용 불가', 167.25, 565.5, 139.0, 198.0, 557.0, 574.0, 0.9985201060771942]]
# [automation.py] ================================================
# [automation.py] adb0 0 1 0 0 0 0
# [automation.py] adb1 0 0 0 0 0 1
# [automation.py] adb3 stamina: 66
# [automation.py] [['수령', 447.5, 433.5, 429.0, 466.0, 421.0, 446.0, 0.999882698059082], ['수령', 448.0, 558.0, 429.0, 467.0, 546.0, 570.0, 0.9997953772544861], ['이동', 447.25, 683.0, 425.0, 469.0, 667.0, 699.0, 0.9996850490570068]]
# [automation.py] []
# [automation.py] adb2 시작
# [automation.py] []
# [automation.py] adb1 시작
# [automation.py] adb0 시작
# [automation.py] adb2 0 0 0 0 0 1
# [automation.py] ================================================
# [automation.py] adb2 비어있는 큐 존재
# [automation.py] [['L14치타 공격', 176.875, 267.5, 117.0, 218.0, 258.0, 277.0, 0.9994477033615112], ['00:01:01', 168.5, 290.0, 143.0, 194.0, 283.0, 297.0, 0.9446082711219788], ['행군 대열2', 164.5, 322.5, 133.0, 202.0, 315.0, 330.0, 0.9577412307262421], ['한가함', 167.5, 345.0, 145.0, 190.0, 334.0, 356.0, 0.9989218711853027], ['행군 대열3', 165.0, 378.25, 133.0, 202.0, 371.0, 386.0, 0.9989880323410034], ['해제하기', 168.0, 401.0, 139.0, 197.0, 392.0, 410.0, 0.9996952414512634], ['행군 대열4', 165.75, 432.25, 133.0, 204.0, 424.0, 441.0, 0.9993603527545929], ['사용불가', 168.5, 455.5, 138.0, 199.0, 447.0, 464.0, 0.9989684820175171], ['행군 대열5', 164.0, 487.0, 133.0, 202.0, 479.0, 495.0, 0.9995012581348419], ['사용불가', 168.5, 510.5, 138.0, 199.0, 502.0, 519.0, 0.9937803149223328], ['행군 대열6', 165.0, 542.5, 133.0, 203.0, 535.0, 550.0, 0.9997338652610779], ['사용 불가', 167.25, 565.5, 139.0, 198.0, 557.0, 574.0, 0.998542070388794]]
# [automation.py] ================================================
# [automation.py] adb1 0 0 0 0 0 1
# [automation.py] adb0 0 1 0 0 0 0
# [automation.py] adb2 stamina: 67
# [automation.py] []
# [automation.py] []
# [automation.py] adb1 시작
# [automation.py] adb2 과학기술 연구 시작작
# [automation.py] [['수령', 447.5, 433.5, 429.0, 466.0, 421.0, 446.0, 0.999882698059082], ['이동', 447.5, 558.5, 428.0, 467.0, 546.0, 571.0, 0.9998134970664978], ['이동', 447.25, 682.5, 426.0, 468.0, 668.0, 697.0, 0.9996277689933777]]
# [automation.py] adb0 시작
# [automation.py] adb1 0 0 0 0 0 1
# [automation.py] adb3 시작
# [automation.py] adb0 0 1 0 0 0 0
# [automation.py] adb3 0 0 0 0 0 1
# [automation.py] []
# [automation.py] adb1 시작
# [automation.py] []
# [automation.py] adb0 시작adb1
# [automation.py]  0 0 0 0 0 1
# [automation.py] adb3 시작

# %%
import subprocess

bluestacks_process_names = ["HD-Player.exe", "HD-Adb.exe", "BstkDrv.exe"]
for proc_name in bluestacks_process_names:
    try:
        subprocess.run(
            ["taskkill", "/F", "/IM", proc_name],
            capture_output=True,
            timeout=10,
        )
    except (subprocess.TimeoutExpired, FileNotFoundError, Exception):
        pass
